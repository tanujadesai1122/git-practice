# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujadesai1122/git-practice/blob/main/libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

project_name = "Smart_Voice_Document_Assistant"

folders = [
    "uploads",
    "audio",
    "vector_db",
    "output",
    "templates",
    "static",
    "static/css",
    "static/js",
    "static/images"
]

os.makedirs(project_name, exist_ok=True)

for folder in folders:
    os.makedirs(os.path.join(project_name, folder), exist_ok=True)

print("Project folders created successfully!")
# Out:
# Project folders created successfully!

# %%
# !find Smart_Voice_Document_Assistant
# Out:
# Smart_Voice_Document_Assistant
# Smart_Voice_Document_Assistant/uploads
# Smart_Voice_Document_Assistant/templates
# Smart_Voice_Document_Assistant/static
# Smart_Voice_Document_Assistant/static/css
# Smart_Voice_Document_Assistant/static/js
# Smart_Voice_Document_Assistant/static/images
# Smart_Voice_Document_Assistant/audio
# Smart_Voice_Document_Assistant/vector_db
# Smart_Voice_Document_Assistant/output

# %%
# !pip install -q google-genai

# %%
# !pip install -q sentence-transformers

# %%
# !pip install -q faiss-cpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 39.8 MB/s eta 0:00:00

# %%
# !pip install -q pypdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 2.1 MB/s eta 0:00:00

# %%
# !pip install -q python-docx
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 2.1 MB/s eta 0:00:00

# %%
# !pip install -q python-pptx
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 12.8 MB/s eta 0:00:00

# %%
# !pip install -q SpeechRecognition
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 34.1 MB/s eta 0:00:00

# %%
# !pip install -q edge-tts

# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 55.0 MB/s eta 0:00:00

# %%
# !pip install -q pandas

# %%
# !pip install -q numpy

# %%
from google import genai
import numpy as np
import pandas as pd
import speech_recognition as sr

print("All libraries installed successfully.")
# Out:
# All libraries installed successfully.
